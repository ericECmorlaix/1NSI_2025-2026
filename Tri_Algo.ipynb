# %% [markdown]
# # Algorithmes de tri
#
# ## Tri par Sélection
#
# Le tri par selection consiste à  identifier la plus petite valeur de la liste puis on la place en première place puis ainsi de suite
#
# cout quadratique

# %%
def tri_selection(tableau):
    for i in range(len(tableau) - 1):
        min = i # Indice 
        for j in range(i + 1, len(tableau)): 
            if tableau[j] < tableau[min]:
                min = j
        valeur_tampon = tableau[i] #On échange les valeurs
        tableau[i] = tableau[min]
        tableau[min] = valeur_tampon
    return tableau

# %% [markdown]
# ## Tri par insertion
#
# Le tri par insertion consiste à prendre le premier élement d´une liste qu´on insère dans une nouvelle liste puis pour chaque élement de la première liste on compare avec les éléments de la deuxième liste pour les placer correctement.
#
# cout quadratique

# %%
def tri_insertion(tableau):
    for i in range(len(tableau)):
        valeur_tampon = tableau[i] # Valeur à insérer
        j = i
        while j > 0 and tableau[j - 1] > valeur_tampon:
            tableau[j] = tableau[j - 1]
            j = j - 1
        tableau[j] = valeur_tampon
    return tableau

# %%
from metakernel import register_ipython_magics
register_ipython_magics()

# %%
# %%tutor
#
# def tri_selection(tableau):
#     for i in range(len(tableau) - 1):
#         min = i # Indice
#         for j in range(i + 1, len(tableau)):
#             if tableau[j] < tableau[min]:
#                 min = j
#         valeur_tampon = tableau[i] #On échange les valeurs
#         tableau[i] = tableau[min]
#         tableau[min] = valeur_tampon
#     return tableau
#
# tri_selection([4,7,3,1])
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://pythontutor.com/iframe-embed.html#code=%0Adef%20tri_selection%28tableau%29%3A%0A%20%20%20%20for%20i%20in%20range%28len%28tableau%29%20-%201%29%3A%0A%20%20%20%20%20%20%20%20min%20%3D%20i%20%23%20Indice%20%0A%20%20%20%20%20%20%20%20for%20j%20in%20range%28i%20%2B%201%2C%20len%28tableau%29%29%3A%20%0A%20%20%20%20%20%20%20%20%20%20%20%20if%20tableau%5Bj%5D%20%3C%20tableau%5Bmin%5D%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20min%20%3D%20j%0A%20%20%20%20%20%20%20%20valeur_tampon%20%3D%20tableau%5Bi%5D%20%23On%20%C3%A9change%20les%20valeurs%0A%20%20%20%20%20%20%20%20tableau%5Bi%5D%20%3D%20tableau%5Bmin%5D%0A%20%20%20%20%20%20%20%20tableau%5Bmin%5D%20%3D%20valeur_tampon%0A%20%20%20%20return%20tableau%0A%0Atri_selection%28%5B4%2C7%2C3%2C1%5D%29%0A&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&py=3&rawInputLstJSON=%5B%5D&curInstr=0&codeDivWidth=350&codeDivHeight=400"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %%tutor
#
# def tri_insertion(tableau):
#     for i in range(len(tableau)):
#         valeur_tampon = tableau[i] # Valeur à insérer
#         j = i
#         while j > 0 and tableau[j - 1] > valeur_tampon:
#             tableau[j] = tableau[j - 1]
#             j = j - 1
#         tableau[j] = valeur_tampon
#     return tableau
#
# tri_insertion([4,7,3,1])
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://pythontutor.com/iframe-embed.html#code=%0Adef%20tri_insertion%28tableau%29%3A%0A%20%20%20%20for%20i%20in%20range%28len%28tableau%29%29%3A%0A%20%20%20%20%20%20%20%20valeur_tampon%20%3D%20tableau%5Bi%5D%20%23%20Valeur%20%C3%A0%20ins%C3%A9rer%0A%20%20%20%20%20%20%20%20j%20%3D%20i%0A%20%20%20%20%20%20%20%20while%20j%20%3E%200%20and%20tableau%5Bj%20-%201%5D%20%3E%20valeur_tampon%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20tableau%5Bj%5D%20%3D%20tableau%5Bj%20-%201%5D%0A%20%20%20%20%20%20%20%20%20%20%20%20j%20%3D%20j%20-%201%0A%20%20%20%20%20%20%20%20tableau%5Bj%5D%20%3D%20valeur_tampon%0A%20%20%20%20return%20tableau%0A%0Atri_insertion%28%5B4%2C7%2C3%2C1%5D%29%0A&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&py=3&rawInputLstJSON=%5B%5D&curInstr=0&codeDivWidth=350&codeDivHeight=400"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
